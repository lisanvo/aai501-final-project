# %%
pip install --upgrade google-cloud-texttospeech
# Out:
# Collecting google-cloud-texttospeech
#   Downloading google_cloud_texttospeech-2.14.1-py2.py3-none-any.whl (118 kB)
#      -------------------------------------- 119.0/119.0 kB 1.8 MB/s eta 0:00:00
# Collecting google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0 (from google-cloud-texttospeech)
#   Downloading google_api_core-2.11.1-py3-none-any.whl (120 kB)
#      -------------------------------------- 120.5/120.5 kB 7.4 MB/s eta 0:00:00
# Collecting proto-plus<2.0.0dev,>=1.22.0 (from google-cloud-texttospeech)
#   Downloading proto_plus-1.22.3-py3-none-any.whl (48 kB)
#      ---------------------------------------- 48.1/48.1 kB 2.4 MB/s eta 0:00:00
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 (from google-cloud-texttospeech)
#   Downloading protobuf-4.24.0-cp39-cp39-win_amd64.whl (430 kB)
#      -------------------------------------- 430.6/430.6 kB 6.8 MB/s eta 0:00:00
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech)
#   Downloading googleapis_common_protos-1.60.0-py2.py3-none-any.whl (227 kB)
#      -------------------------------------- 227.6/227.6 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in c:\users\mmoll009\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (2.16.1)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\mmoll009\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (2.27.1)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\mmoll009\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (1.42.0)
# Collecting grpcio-status<2.0.dev0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech)
#   Downloading grpcio_status-1.56.2-py3-none-any.whl (5.1 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\mmoll009\anaconda3\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\mmoll009\anaconda3\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in c:\users\mmoll009\anaconda3\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\mmoll009\anaconda3\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (4.7.2)
# Collecting grpcio<2.0dev,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech)
#   Downloading grpcio-1.56.2-cp39-cp39-win_amd64.whl (4.2 MB)
#      ---------------------------------------- 4.2/4.2 MB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mmoll009\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mmoll009\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\mmoll009\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mmoll009\anaconda3\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (3.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\mmoll009\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (0.4.8)
# Installing collected packages: protobuf, grpcio, proto-plus, googleapis-common-protos, grpcio-status, google-api-core, google-cloud-texttospeech
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.1
#     Uninstalling protobuf-3.19.1:
#       Successfully uninstalled protobuf-3.19.1
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.42.0
#     Uninstalling grpcio-1.42.0:
#       Successfully uninstalled grpcio-1.42.0
#   Attempting uninstall: googleapis-common-protos
#     Found existing installation: googleapis-common-protos 1.53.0
#     Uninstalling googleapis-common-protos-1.53.0:
#       Successfully uninstalled googleapis-common-protos-1.53.0
#   Attempting uninstall: google-api-core
#     Found existing installation: google-api-core 1.25.1
#     Uninstalling google-api-core-1.25.1:
#       Successfully uninstalled google-api-core-1.25.1
# Successfully installed google-api-core-2.11.1 google-cloud-texttospeech-2.14.1 googleapis-common-protos-1.60.0 grpcio-1.56.2 grpcio-status-1.56.2 proto-plus-1.22.3 protobuf-4.24.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-core 1.7.1 requires google-api-core<2.0.0dev,>=1.21.0, but you have google-api-core 2.11.1 which is incompatible.
# google-cloud-core 1.7.1 requires google-auth<2.0dev,>=1.24.0, but you have google-auth 2.16.1 which is incompatible.
# google-cloud-storage 1.31.0 requires google-auth<2.0dev,>=1.11.0, but you have google-auth 2.16.1 which is incompatible.
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install argparse google-cloud-texttospeech gtts moviepy pdf2image python-pptx
# Out:
# Collecting argparse
#   Downloading argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: google-cloud-texttospeech in c:\users\mmoll009\anaconda3\lib\site-packages (2.14.1)
# Requirement already satisfied: gtts in c:\users\mmoll009\anaconda3\lib\site-packages (2.3.2)
# Requirement already satisfied: moviepy in c:\users\mmoll009\anaconda3\lib\site-packages (1.0.3)
# Requirement already satisfied: pdf2image in c:\users\mmoll009\anaconda3\lib\site-packages (1.16.3)
# Requirement already satisfied: python-pptx in c:\users\mmoll009\anaconda3\lib\site-packages (0.6.21)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0 in c:\users\mmoll009\anaconda3\lib\site-packages (from google-cloud-texttospeech) (2.11.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in c:\users\mmoll009\anaconda3\lib\site-packages (from google-cloud-texttospeech) (1.22.3)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in c:\users\mmoll009\anaconda3\lib\site-packages (from google-cloud-texttospeech) (4.24.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\mmoll009\anaconda3\lib\site-packages (from gtts) (2.27.1)
# Requirement already satisfied: click<8.2,>=7.1 in c:\users\mmoll009\anaconda3\lib\site-packages (from gtts) (8.0.4)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in c:\users\mmoll009\anaconda3\lib\site-packages (from moviepy) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in c:\users\mmoll009\anaconda3\lib\site-packages (from moviepy) (4.64.0)
# Requirement already satisfied: proglog<=1.0.0 in c:\users\mmoll009\anaconda3\lib\site-packages (from moviepy) (0.1.10)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\mmoll009\anaconda3\lib\site-packages (from moviepy) (1.21.5)
# Requirement already satisfied: imageio<3.0,>=2.5 in c:\users\mmoll009\anaconda3\lib\site-packages (from moviepy) (2.9.0)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in c:\users\mmoll009\anaconda3\lib\site-packages (from moviepy) (0.4.8)
# Requirement already satisfied: pillow in c:\users\mmoll009\anaconda3\lib\site-packages (from pdf2image) (9.0.1)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\mmoll009\anaconda3\lib\site-packages (from python-pptx) (4.9.2)
# Requirement already satisfied: XlsxWriter>=0.5.7 in c:\users\mmoll009\anaconda3\lib\site-packages (from python-pptx) (3.0.3)
# Requirement already satisfied: colorama in c:\users\mmoll009\anaconda3\lib\site-packages (from click<8.2,>=7.1->gtts) (0.4.4)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\mmoll009\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (1.60.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in c:\users\mmoll009\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (2.16.1)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\mmoll009\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (1.56.2)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\mmoll009\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (1.56.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mmoll009\anaconda3\lib\site-packages (from requests<3,>=2.27->gtts) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mmoll009\anaconda3\lib\site-packages (from requests<3,>=2.27->gtts) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\mmoll009\anaconda3\lib\site-packages (from requests<3,>=2.27->gtts) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mmoll009\anaconda3\lib\site-packages (from requests<3,>=2.27->gtts) (3.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\mmoll009\anaconda3\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\mmoll009\anaconda3\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in c:\users\mmoll009\anaconda3\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\mmoll009\anaconda3\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (4.7.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\mmoll009\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-texttospeech) (0.4.8)
# Installing collected packages: argparse
# Successfully installed argparse-1.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install python-pptx
# Out:
# Collecting python-pptx
#   Downloading python-pptx-0.6.21.tar.gz (10.1 MB)
#      ---------------------------------------- 10.1/10.1 MB 6.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: lxml>=3.1.0 in c:\users\mmoll009\anaconda3\lib\site-packages (from python-pptx) (4.9.2)
# Requirement already satisfied: Pillow>=3.3.2 in c:\users\mmoll009\anaconda3\lib\site-packages (from python-pptx) (9.0.1)
# Requirement already satisfied: XlsxWriter>=0.5.7 in c:\users\mmoll009\anaconda3\lib\site-packages (from python-pptx) (3.0.3)
# Building wheels for collected packages: python-pptx
#   Building wheel for python-pptx (setup.py): started
#   Building wheel for python-pptx (setup.py): finished with status 'done'
#   Created wheel for python-pptx: filename=python_pptx-0.6.21-py3-none-any.whl size=470951 sha256=8a8c40b269ab1a59fc38d854a68120d75607786be0cbcff55f42314333369b64
#   Stored in directory: c:\users\mmoll009\appdata\local\pip\cache\wheels\0e\4a\ed\9653bc799915f52dce3f04d14946fbd85cce9c3cdedc9cfa71
# Successfully built python-pptx
# Installing collected packages: python-pptx
# Successfully installed python-pptx-0.6.21
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pdf2image
# Out:
# Collecting pdf2image
#   Downloading pdf2image-1.16.3-py3-none-any.whl (11 kB)
# Requirement already satisfied: pillow in c:\users\mmoll009\anaconda3\lib\site-packages (from pdf2image) (9.0.1)
# Installing collected packages: pdf2image
# Successfully installed pdf2image-1.16.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install moviepy
# Out:
# Collecting moviepy
#   Downloading moviepy-1.0.3.tar.gz (388 kB)
#      -------------------------------------- 388.3/388.3 kB 2.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting decorator<5.0,>=4.0.2 (from moviepy)
#   Downloading decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in c:\users\mmoll009\anaconda3\lib\site-packages (from moviepy) (4.64.0)
# Requirement already satisfied: requests<3.0,>=2.8.1 in c:\users\mmoll009\anaconda3\lib\site-packages (from moviepy) (2.27.1)
# Collecting proglog<=1.0.0 (from moviepy)
#   Downloading proglog-0.1.10-py3-none-any.whl (6.1 kB)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\mmoll009\anaconda3\lib\site-packages (from moviepy) (1.21.5)
# Requirement already satisfied: imageio<3.0,>=2.5 in c:\users\mmoll009\anaconda3\lib\site-packages (from moviepy) (2.9.0)
# Collecting imageio_ffmpeg>=0.2.0 (from moviepy)
#   Downloading imageio_ffmpeg-0.4.8-py3-none-win_amd64.whl (22.6 MB)
#      ---------------------------------------- 22.6/22.6 MB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: pillow in c:\users\mmoll009\anaconda3\lib\site-packages (from imageio<3.0,>=2.5->moviepy) (9.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mmoll009\anaconda3\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mmoll009\anaconda3\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\mmoll009\anaconda3\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mmoll009\anaconda3\lib\site-packages (from requests<3.0,>=2.8.1->moviepy) (3.3)
# Requirement already satisfied: colorama in c:\users\mmoll009\anaconda3\lib\site-packages (from tqdm<5.0,>=4.11.2->moviepy) (0.4.4)
# Building wheels for collected packages: moviepy
#   Building wheel for moviepy (setup.py): started
#   Building wheel for moviepy (setup.py): finished with status 'done'
#   Created wheel for moviepy: filename=moviepy-1.0.3-py3-none-any.whl size=110743 sha256=fa87f5d7805dd59af939e177de22aec91ad89e7810c2d2c3f0d43da53355f4b5
#   Stored in directory: c:\users\mmoll009\appdata\local\pip\cache\wheels\29\15\e4\4f790bec6acd51a00b67e8ee1394f0bc6e0135c315f8ff399a
# Successfully built moviepy
# Installing collected packages: imageio_ffmpeg, decorator, proglog, moviepy
#   Attempting uninstall: decorator
#     Found existing installation: decorator 5.1.1
#     Uninstalling decorator-5.1.1:
#       Successfully uninstalled decorator-5.1.1
# Successfully installed decorator-4.4.2 imageio_ffmpeg-0.4.8 moviepy-1.0.3 proglog-0.1.10
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.1.5 requires pyqt5<5.13, which is not installed.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.

# %%
pip install gtts
# Out:
# Collecting gtts
#   Downloading gTTS-2.3.2-py3-none-any.whl (28 kB)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\mmoll009\anaconda3\lib\site-packages (from gtts) (2.27.1)
# Requirement already satisfied: click<8.2,>=7.1 in c:\users\mmoll009\anaconda3\lib\site-packages (from gtts) (8.0.4)
# Requirement already satisfied: colorama in c:\users\mmoll009\anaconda3\lib\site-packages (from click<8.2,>=7.1->gtts) (0.4.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mmoll009\anaconda3\lib\site-packages (from requests<3,>=2.27->gtts) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mmoll009\anaconda3\lib\site-packages (from requests<3,>=2.27->gtts) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\mmoll009\anaconda3\lib\site-packages (from requests<3,>=2.27->gtts) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mmoll009\anaconda3\lib\site-packages (from requests<3,>=2.27->gtts) (3.3)
# Installing collected packages: gtts
# Successfully installed gtts-2.3.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
 pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\mmoll009\anaconda3\lib\site-packages (23.1.2)
# Collecting pip
#   Downloading pip-23.2.1-py3-none-any.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 3.2 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.1.2
#     Uninstalling pip-23.1.2:
#       Successfully uninstalled pip-23.1.2
# Successfully installed pip-23.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import argparse
import os
import shutil
import subprocess
from typing import List

import numpy as np
from google.cloud import texttospeech as tts
from gtts import gTTS
from moviepy.audio.AudioClip import AudioArrayClip
from moviepy.editor import (
    AudioFileClip,
    ImageClip,
    VideoFileClip,
    concatenate_audioclips,
    concatenate_videoclips,
)
from moviepy.video.compositing.transitions import crossfadein, crossfadeout
from pdf2image import convert_from_path
from pptx import Presentation


class PPTXtoVideo:
    """
    A class to automate the creation of a video presentation from a PowerPoint file.
    """

    def __init__(self, pptx_filename: str):
        self.pptx_filename = pptx_filename
        self.pdf_filename = pptx_filename.replace(".pptx", ".pdf")
        self.output_file = pptx_filename.replace(".pptx", ".mp4")
        self.presentation = Presentation(pptx_filename)
        self.slides = self.presentation.slides
        self.voiceover_texts = [
            slide.notes_slide.notes_text_frame.text for slide in self.slides
        ]

    def text_to_wav(self, text: str, filename: str, voice_name: str = "en-US-Studio-M"):
        """
        Converts the given text to speech and saves it as a .wav file.

        If the GOOGLE_APPLICATION_CREDENTIALS environment variable is set, this method uses
        Google Cloud Text-to-Speech to generate the speech. Otherwise, it uses gTTS.

        Args:
            text (str): The text to convert to speech.
            filename (str): The name of the .wav file to save the speech to.
            voice_name (str, optional): The name of the voice to use for speech generation.
                This should be a voice name from Google Cloud Text-to-Speech (e.g., "en-US-Studio-M").
                Defaults to "en-US-Studio-M".
        """
        # USE PROFESSIONAL VOICES FROM GOOGLE CLOUD
        if "GOOGLE_APPLICATION_CREDENTIALS" in os.environ:
            language_code = "-".join(voice_name.split("-")[:2])
            text_input = tts.SynthesisInput(text=text)
            voice_params = tts.VoiceSelectionParams(
                language_code=language_code, name=voice_name
            )
            audio_config = tts.AudioConfig(audio_encoding=tts.AudioEncoding.LINEAR16)
            client = tts.TextToSpeechClient()

            response = client.synthesize_speech(
                input=text_input,
                voice=voice_params,
                audio_config=audio_config,
            )

            with open(filename, "wb") as out:
                out.write(response.audio_content)
        # USE FREE NON-PROFESSIONAL VOICES FROM GTTS
        else:
            voice = gTTS(text=text, lang="en", slow=False)
            voice.save(filename)

    def format_duration(self, duration: int) -> str:
        """
        Formats a duration in seconds into a string in the format 'mm:ss'.

        Args:
            duration (int): Duration in seconds.

        Returns:
            str: Formatted duration string.
        """
        minutes, seconds = divmod(int(duration), 60)
        return f"{minutes}:{seconds:02}"

    def write_metadata(self, videos: List[AudioFileClip]):
        """
        Writes metadata to a text file.

        Args:
            videos (List[AudioFileClip]): List of video clips.
        """
        total_duration = sum(video.duration for video in videos)
        with open(self.pptx_filename.replace(".pptx", ".txt"), "w") as f:
            f.write(f"Total duration: {self.format_duration(total_duration)}\n")
            for i, video in enumerate(videos):
                f.write(f"\nSlide {i+1}:\n")
                f.write(f"Duration: {self.format_duration(video.duration)}\n")
                f.write(f"Voiceover: {self.voiceover_texts[i]}\n")

    def convert_to_pdf(self):
        """
        Converts the .pptx file to a .pdf file using LibreOffice.
        """
        cmd = f"libreoffice --headless --convert-to pdf {self.pptx_filename}"
        subprocess.run(cmd, shell=True, check=True)

    def create_videos(self) -> List[AudioFileClip]:
        """
        Creates a video for each slide with a voiceover.

        Returns:
            List[AudioFileClip]: List of video clips.
        """
        videos = []
        assets_dir = "assets"
        if os.path.exists(assets_dir):
            shutil.rmtree(assets_dir)
        os.makedirs(assets_dir, exist_ok=True)
        for i, _ in enumerate(self.slides):
            text = self.voiceover_texts[i]
            images = convert_from_path(self.pdf_filename, dpi=300)
            images[i].save(f"{assets_dir}/slide_{i}.png", "PNG")
            voice_filename = f"{assets_dir}/voice_{i}.wav"
            self.text_to_wav(text, voice_filename)
            audio = AudioFileClip(voice_filename)
            # Create a silent audio clip of 0.5 seconds
            silence = AudioArrayClip(np.array([[0], [0]]), fps=44100).set_duration(0.5)
            # Add silence to the beginning and end of the audio
            audio = concatenate_audioclips([silence, audio, silence])
            img_clip = ImageClip(f"{assets_dir}/slide_{i}.png", duration=audio.duration)
            video = img_clip.set_audio(audio)
            videos.append(video)
        return videos

    def combine_videos(self, videos: List[AudioFileClip]):
        """
        Combines all the videos into one video.

        Args:
            videos (List[AudioFileClip]): List of video clips.
        """
        intro_clip = VideoFileClip("stock/intro.mp4")
        final_clip = concatenate_videoclips(videos, method="compose")
        final_clip.write_videofile(self.output_file, fps=24)

    def convert(self):
        """
        Converts the PowerPoint presentation to a video.
        """
        self.convert_to_pdf()
        videos = self.create_videos()
        self.write_metadata(videos)
        self.combine_videos(videos)


def main():
    """
    Main function to test the PPTXtoVideo class.
    """
    parser = argparse.ArgumentParser(
        description="Convert a PowerPoint presentation to a video."
    )

    parser.add_argument(
        "pptx",
        type=str,
        help="The name of the PowerPoint file to convert.",
    )

    parser.add_argument(
        "--keyfile",
        type=str,
        help="The path to the Google service account JSON file.",
        required=False,
    )

    args = parser.parse_args()

    if args.keyfile:
        os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = args.keyfile

    PPTXtoVideo(args.pptx).convert()


if __name__ == "__main__":
    main()
# Out:
# usage: ipykernel_launcher.py [-h] [--keyfile KEYFILE] pptx
# ipykernel_launcher.py: error: the following arguments are required: pptx
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
